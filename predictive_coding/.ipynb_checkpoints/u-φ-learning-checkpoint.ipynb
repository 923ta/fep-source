# %%
import numpy as np
from scipy.stats import norm 
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
Us = list(range(30))
sigma_u = 1
vp = 1
sigma_p = 1
v = np.arange(0.01, 5, 0.01)

dt = 0.01

# %%
for u in Us:
    phi = list(range(500))
    phi[0] = vp
    ep = list(range(500))
    ep[0] = 0
    eu = list(range(500))
    eu[0] = (u - phi[0]**2) / sigma_u
    
    for j in range(1, 500):
            phi[j] = phi[j-1] + dt * (-ep[j-1] + eu[j-1] * (2 * phi[j-1]))
            ep[j] = ep[j-1] + dt * (phi[j-1] - vp - sigma_p * ep[j-1])
            eu[j] = eu[j-1] + dt * (u - phi[j-1] ** 2 - sigma_u * eu[j-1])
            
            
    plt

# %%
for k in range(50):
    ims = []
    for i in range(1, 50):
        # 推測
        for j in range(1, 500):
            phi[j] = phi[j-1] + dt * (-ep[j-1] + eu[j-1] * (2 * phi[j-1]))
            ep[j] = ep[j-1] + dt * (phi[j-1] - vp - sigma_p * ep[j-1])
            eu[j] = eu[j-1] + dt * (u - phi[j-1] ** 2 - sigma_u * eu[j-1])

        phi[0] = phi[-1]
        ep[0] = ep[-1]
        eu[0] = eu[-1]

        # 学習
        vp = vp + ep[-1] * dt
        sigma_p = max(sigma_p + 1/2 * (ep[-1]**2 - 1/sigma_p), 1)
        sigma_u = max(sigma_u + 1/2 * (eu[-1]**2 - 1/sigma_u), 1) 

    PUV = norm.pdf(u, v**2, sigma_u)
    PV = norm.pdf(v, vp, sigma_p)
    numer = PUV * PV
    denom = np.sum(numer * dt) # 分母＝分子をvで積分
    PVU = numer / denom

#     fig = plt.figure()
#     plt.plot(v, PV, color='r', label='p(v)')
#     plt.plot(v, PUV, color='g', label='p(u|v)')
#     plt.plot(v, PVU, color='b', label='p(v|u)')
#     plt.vlines(np.argmax(PV)/100, -0.05, 1.4, color='#7d7d7d', linestyle='dotted')
#     plt.xlabel('v')
#     plt.legend()
#     plt.ylim(0, 1.4)
#     plt.annotate(np.argmax(PV)/100, (np.argmax(PV)/100, -0), (3.5, 0.6), arrowprops=dict(arrowstyle="->"), fontsize='xx-large')
#     plt.grid()
#     plt.show()
    print(k, "回目")
    print("vp:", vp)
    print("sigma_p:", sigma_p)
    print("sigma_u:" , sigma_u)
    
# ani = animation.ArtistAnimation(fig, ims, interval=100)
# ani.save("output.gif", writer="imagemagick")
# Out:
# 0 回目
# vp: 1.1462002261902355
# sigma_p: 1
# sigma_u: 1
# 1 回目
# vp: 1.2409459510314214
# sigma_p: 1
# sigma_u: 1
# 2 回目
# vp: 1.3022516933086583
# sigma_p: 1
# sigma_u: 1
# 3 回目
# vp: 1.3418880305711487
# sigma_p: 1
# sigma_u: 1
# 4 回目
# vp: 1.367501433108656
# sigma_p: 1
# sigma_u: 1
# 5 回目
# vp: 1.3840477988901994
# sigma_p: 1
# sigma_u: 1
# 6 回目
# vp: 1.3947346486585677
# sigma_p: 1
# sigma_u: 1
# 7 回目
# vp: 1.401636097190464
# sigma_p: 1
# sigma_u: 1
# 8 回目
# vp: 1.4060926031143035
# sigma_p: 1
# sigma_u: 1
# 9 回目
# vp: 1.408970169512986
# sigma_p: 1
# sigma_u: 1
# 10 回目
# vp: 1.410828150061306
# sigma_p: 1
# sigma_u: 1
# 11 回目
# vp: 1.4120277799144982
# sigma_p: 1
# sigma_u: 1
# 12 回目
# vp: 1.4128023257168458
# sigma_p: 1
# sigma_u: 1
# 13 回目
# vp: 1.41330240965247
# sigma_p: 1
# sigma_u: 1
# 14 回目
# vp: 1.4136252858984009
# sigma_p: 1
# sigma_u: 1
# 15 回目
# vp: 1.4138337482357997
# sigma_p: 1
# sigma_u: 1
# 16 回目
# vp: 1.413968339856981
# sigma_p: 1
# sigma_u: 1
# 17 回目
# vp: 1.4140552374494044
# sigma_p: 1
# sigma_u: 1
# 18 回目
# vp: 1.4141113418608693
# sigma_p: 1
# sigma_u: 1
# 19 回目
# vp: 1.414147564991785
# sigma_p: 1
# sigma_u: 1
# 20 回目
# vp: 1.4141709520055454
# sigma_p: 1
# sigma_u: 1
# 21 回目
# vp: 1.414186051535744
# sigma_p: 1
# sigma_u: 1
# 22 回目
# vp: 1.4141958003550357
# sigma_p: 1
# sigma_u: 1
# 23 回目
# vp: 1.4142020945552662
# sigma_p: 1
# sigma_u: 1
# 24 回目
# vp: 1.4142061583246683
# sigma_p: 1
# sigma_u: 1
# 25 回目
# vp: 1.414208782044974
# sigma_p: 1
# sigma_u: 1
# 26 回目
# vp: 1.4142104760160987
# sigma_p: 1
# sigma_u: 1
# 27 回目
# vp: 1.4142115697066522
# sigma_p: 1
# sigma_u: 1
# 28 回目
# vp: 1.4142122758338072
# sigma_p: 1
# sigma_u: 1
# 29 回目
# vp: 1.4142127317356639
# sigma_p: 1
# sigma_u: 1
# 30 回目
# vp: 1.4142130260827954
# sigma_p: 1
# sigma_u: 1
# 31 回目
# vp: 1.4142132161242094
# sigma_p: 1
# sigma_u: 1
# 32 回目
# vp: 1.4142133388219866
# sigma_p: 1
# sigma_u: 1
# 33 回目
# vp: 1.4142134180402177
# sigma_p: 1
# sigma_u: 1
# 34 回目
# vp: 1.414213469186443
# sigma_p: 1
# sigma_u: 1
# 35 回目
# vp: 1.41421350220834
# sigma_p: 1
# sigma_u: 1
# 36 回目
# vp: 1.4142135235285007
# sigma_p: 1
# sigma_u: 1
# 37 回目
# vp: 1.4142135372935856
# sigma_p: 1
# sigma_u: 1
# 38 回目
# vp: 1.414213546180834
# sigma_p: 1
# sigma_u: 1
# 39 回目
# vp: 1.414213551918772
# sigma_p: 1
# sigma_u: 1
# 40 回目
# vp: 1.4142135556233977
# sigma_p: 1
# sigma_u: 1
# 41 回目
# vp: 1.4142135580152408
# sigma_p: 1
# sigma_u: 1
# 42 回目
# vp: 1.4142135595595027
# sigma_p: 1
# sigma_u: 1
# 43 回目
# vp: 1.414213560556535
# sigma_p: 1
# sigma_u: 1
# 44 回目
# vp: 1.4142135612002569
# sigma_p: 1
# sigma_u: 1
# 45 回目
# vp: 1.4142135616158673
# sigma_p: 1
# sigma_u: 1
# 46 回目
# vp: 1.4142135618842009
# sigma_p: 1
# sigma_u: 1
# 47 回目
# vp: 1.414213562057447
# sigma_p: 1
# sigma_u: 1
# 48 回目
# vp: 1.4142135621693013
# sigma_p: 1
# sigma_u: 1
# 49 回目
# vp: 1.4142135622415175
# sigma_p: 1
# sigma_u: 1
